# %%
#initial setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#import API key
from api_keys import weather_api_key

#add citipy to determine lat and long
from citipy import citipy

#output file (CSV)
output_data_file = "output_data/cities.csv"

#range of lat and long
lat_cities = (-90, 90)
lng_cities = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
#list for holding lat and long and cities
lat_lng = []
cities = []

#create random list
lats = np.random.uniform(lat_cities[0], lat_cities[1], size = 1500)
longs = np.random.uniform(lng_cities[0], lng_cities[1], size = 1500)
lat_lng = zip(lats, longs)

#identify closest city for each combination
for lat_lng in lat_lng:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #if the city is unique then add to cities list
    if city not in cities:
        cities.append(city)
#print citiy count
len(cities)
# Out:
# 603

# %%
cities
# Out:
# ['thompson',
#  'putina',
#  'sandanski',
#  'bredasdorp',
#  'illoqqortoormiut',
#  'neryungri',
#  'imbituba',
#  'grand river south east',
#  'upernavik',
#  'rikitea',
#  'hasaki',
#  'yellowknife',
#  'haibowan',
#  'zhanatas',
#  'lebu',
#  'weymouth',
#  'arraial do cabo',
#  'jamestown',
#  'georgetown',
#  'ushuaia',
#  'hermanus',
#  'hobart',
#  'avarua',
#  'uruzgan',
#  'bubaque',
#  'barentsburg',
#  'nioro',
#  'tsihombe',
#  'butaritari',
#  'busselton',
#  'yar-sale',
#  'albany',
#  'novo aripuana',
#  'kapaa',
#  'shache',
#  'ponta do sol',
#  'saint andrews',
#  'uvalde',
#  'san patricio',
#  'kasongo',
#  'naryan-mar',
#  'vaitupu',
#  'talalayivka',
#  'saskylakh',
#  'pevek',
#  'hithadhoo',
#  'vaini',
#  'souillac',
#  'port-gentil',
#  'svetlyy',
#  'cape town',
#  'saint-philippe',
#  'amderma',
#  'vila',
#  'iqaluit',
#  'taolanaro',
#  'inongo',
#  'east london',
#  'chokurdakh',
#  'nanortalik',
#  'yuli',
#  'tashtyp',
#  'cabo san lucas',
#  'punta arenas',
#  'castro',
#  'bulnes',
#  'pilar',
#  'longyearbyen',
#  'dikson',
#  'khatanga',
#  'bethel',
#  'luganville',
#  'barrow',
#  'kaitangata',
#  'puerto ayora',
#  'quatre cocos',
#  'dwarka',
#  'mendahara',
#  'tasiilaq',
#  'port alfred',
#  'jijiga',
#  'mataura',
#  'turukhansk',
#  'nizhneyansk',
#  'caraquet',
#  'gamba',
#  'bluff',
#  'mys shmidta',
#  'porecatu',
#  'burgersdorp',
#  'mar del plata',
#  'luderitz',
#  'clyde river',
#  'saldanha',
#  'pemangkat',
#  'panguipulli',
#  'saint-paul',
#  'provideniya',
#  'veraval',
#  'meulaboh',
#  'ilulissat',
#  'geresk',
#  'moa',
#  'atuona',
#  'stornoway',
#  'kholbon',
#  'port blair',
#  'boende',
#  'nikolskoye',
#  'selma',
#  'kazachinskoye',
#  'norman wells',
#  'sawtell',
#  'andros town',
#  'carutapera',
#  'homer',
#  'sola',
#  'nahan',
#  'marang',
#  'galdar',
#  'talnakh',
#  'katsina',
#  'brae',
#  'san jeronimo',
#  'tuktoyaktuk',
#  'guerrero negro',
#  'pisco',
#  'nurota',
#  'faya',
#  'kawalu',
#  'saint-georges',
#  'walvis bay',
#  'halifax',
#  'kodiak',
#  'berlevag',
#  'hilo',
#  'seydi',
#  'cordele',
#  'rocha',
#  'hammerfest',
#  'lorengau',
#  'arman',
#  'kasempa',
#  'batamshinskiy',
#  'attawapiskat',
#  'dongsheng',
#  'magugu',
#  'hun',
#  'chapleau',
#  'saint-joseph',
#  'te anau',
#  'comodoro rivadavia',
#  'mehamn',
#  'kailua',
#  'quelimane',
#  'manga',
#  'marawi',
#  'bolonchen',
#  'abu samrah',
#  'chuy',
#  'new norfolk',
#  'sentyabrskiy',
#  'marcona',
#  'qaanaaq',
#  'sande',
#  'alofi',
#  'ngukurr',
#  'wanxian',
#  'umzimvubu',
#  'cairns',
#  'buraydah',
#  'moose factory',
#  'rudsar',
#  'dmitriyevka',
#  'mount gambier',
#  'fortuna',
#  'lagoa',
#  'saint-augustin',
#  'camapua',
#  'sligo',
#  'constitucion',
#  'bambari',
#  'zachagansk',
#  'cidreira',
#  'tuatapere',
#  'jalu',
#  'omboue',
#  'klaksvik',
#  'port hardy',
#  'kushima',
#  'aviles',
#  'christchurch',
#  'flinders',
#  'honningsvag',
#  'torbay',
#  'wajid',
#  'saleilua',
#  'bambous virieux',
#  'mahon',
#  'pangnirtung',
#  'dillon',
#  'peniche',
#  'morehead',
#  'avera',
#  'airai',
#  'samusu',
#  'port elizabeth',
#  'belcista',
#  'saint-francois',
#  'santa cruz de la palma',
#  'rawlins',
#  'caranavi',
#  'durant',
#  'moju',
#  'carnarvon',
#  'sungaipenuh',
#  'chapais',
#  'labuhan',
#  'vadso',
#  'eyl',
#  'tolu',
#  'edd',
#  'vao',
#  'ornes',
#  'havelock',
#  'sao filipe',
#  'palabuhanratu',
#  'svetlogorsk',
#  'komsomolskiy',
#  'erzin',
#  'kunyang',
#  'alugan',
#  'karratha',
#  'zolotkovo',
#  'kabwe',
#  'belushya guba',
#  'lagos',
#  'seoul',
#  'harper',
#  'general roca',
#  'kununurra',
#  'ye',
#  'cangzhou',
#  'bengkulu',
#  'lompoc',
#  'aklavik',
#  'barawe',
#  'belfast',
#  'mikhaylovka',
#  'mayumba',
#  'victoria',
#  'valencia',
#  'alotau',
#  'issoire',
#  'salta',
#  'fort nelson',
#  'khani',
#  'beringovskiy',
#  'muroto',
#  'grand gaube',
#  'adrar',
#  'taltal',
#  'san jose',
#  'opobo',
#  'tiksi',
#  'talcahuano',
#  'krasnyy chikoy',
#  'mecca',
#  'mareeba',
#  'grindavik',
#  'kristiinankaupunki',
#  'cabedelo',
#  'zhaotong',
#  'gashua',
#  'pauini',
#  'rio gallegos',
#  'kruisfontein',
#  'cape coast',
#  'uribia',
#  'okhotsk',
#  'itarema',
#  'lavrentiya',
#  'faanui',
#  'norfolk',
#  'trairi',
#  'sakakah',
#  'ballina',
#  'plastun',
#  'aswan',
#  'young',
#  'north bend',
#  'gucheng',
#  'kahului',
#  'kapoeta',
#  'ponta delgada',
#  'dingle',
#  'ngunguru',
#  'laguna',
#  'osorno',
#  'sampit',
#  'makakilo city',
#  'point pleasant',
#  'salisbury',
#  'chulumani',
#  'carahue',
#  'yumen',
#  'gravelbourg',
#  'srednekolymsk',
#  'eureka',
#  'sitka',
#  'chara',
#  'abhar',
#  'nowa sol',
#  'warri',
#  'coahuayana',
#  'khartoum',
#  'kondinskoye',
#  'severo-kurilsk',
#  'ostrovnoy',
#  'taoudenni',
#  'san quintin',
#  'san cristobal',
#  'kholodnyy',
#  'juneau',
#  'petropavlovsk-kamchatskiy',
#  'mahebourg',
#  'broome',
#  'asau',
#  'arkhangelskoye',
#  'hornepayne',
#  'pokaran',
#  'anton lizardo',
#  'praia',
#  'pacific grove',
#  'abha',
#  'carballo',
#  'malwan',
#  'changji',
#  'muisne',
#  'gigmoto',
#  'san vicente',
#  'aksu',
#  'tuggurt',
#  'hambantota',
#  'egvekinot',
#  'birao',
#  'san juan',
#  'gatesville',
#  'sorland',
#  'ayni',
#  'muriti',
#  'leningradskiy',
#  'carora',
#  'andenes',
#  'puerto escondido',
#  'banda aceh',
#  'kamina',
#  'nuuk',
#  'nola',
#  'boguchany',
#  'hays',
#  'newton',
#  'xichang',
#  'hovd',
#  'qasigiannguit',
#  'husavik',
#  'ruwi',
#  'mount pleasant',
#  'hamilton',
#  'kavieng',
#  'rochester',
#  'vanavara',
#  'vidim',
#  'ribeira grande',
#  'maragogi',
#  'saleaula',
#  'kerema',
#  'toliary',
#  'banjar',
#  'bose',
#  'jingdezhen',
#  'katyuzhanka',
#  'katsuura',
#  'bhuj',
#  'alta floresta',
#  'formosa do rio preto',
#  'salalah',
#  'belogradcik',
#  'tabou',
#  'namibe',
#  'pinhao',
#  'samalaeulu',
#  'waipawa',
#  'leh',
#  'cherskiy',
#  'elva',
#  'krasnyy yar',
#  'cockburn town',
#  'chumikan',
#  'kiunga',
#  'northam',
#  'caramay',
#  'amposta',
#  'sarangani',
#  'vanimo',
#  'san andres',
#  'sumbawa',
#  'mafinga',
#  'perote',
#  'linfen',
#  'chipata',
#  'atar',
#  'half moon bay',
#  'montes claros',
#  'epe',
#  'lephepe',
#  'ciudad bolivar',
#  'codrington',
#  'ketchikan',
#  'shenjiamen',
#  'posse',
#  'chaa-khol',
#  'kolondieba',
#  'opuwo',
#  'ixtapa',
#  'stade',
#  'nemuro',
#  'pontes e lacerda',
#  'ambilobe',
#  'cayenne',
#  'antofagasta',
#  'dingtao',
#  'bow island',
#  'mpanda',
#  'saint anthony',
#  'nalut',
#  'agua prieta',
#  'yemanzhelinsk',
#  'ahipara',
#  'mizan teferi',
#  'hervey bay',
#  'port pirie',
#  'yaan',
#  'doha',
#  'nakhon thai',
#  'calama',
#  'chicaman',
#  'la ronge',
#  'acari',
#  'katangli',
#  'sechura',
#  'bachi-yurt',
#  'mbini',
#  'ust-tsilma',
#  'camana',
#  'dunedin',
#  'saryshagan',
#  'zyryanka',
#  'nanakuli',
#  'nyurba',
#  'praia da vitoria',
#  'meyungs',
#  'aleksandrovka',
#  'knysna',
#  'moindou',
#  'goma',
#  'margate',
#  'ondorhaan',
#  'jiquipilas',
#  'vrangel',
#  'katsiveli',
#  'pimentel',
#  'nepalganj',
#  'glenwood springs',
#  'fairbanks',
#  'rio cuarto',
#  'zalesovo',
#  'pangai',
#  'hay river',
#  'sorvag',
#  'harboore',
#  'mayya',
#  'bur gabo',
#  'nisia floresta',
#  'novopokrovka',
#  'sibu',
#  'jacareacanga',
#  'naze',
#  'ajdabiya',
#  'kudahuvadhoo',
#  'saiha',
#  'nouadhibou',
#  'petropavlovka',
#  'leua',
#  'esperance',
#  'coihaique',
#  'yershichi',
#  'kamenka',
#  'hami',
#  'goderich',
#  'kiknur',
#  'amahai',
#  'port hedland',
#  'mangrol',
#  'hof',
#  'xining',
#  'sines',
#  'broken hill',
#  'buchanan',
#  'mocajuba',
#  'viedma',
#  'dossor',
#  'ginir',
#  'kholm-zhirkovskiy',
#  'porto novo',
#  'tunduru',
#  'kloulklubed',
#  'ugoofaaru',
#  'kupang',
#  'almansa',
#  'novoanninskiy',
#  'thinadhoo',
#  'krasnoselkup',
#  'songea',
#  'bahir dar',
#  'shelburne',
#  'puerto baquerizo moreno',
#  'diffa',
#  'belaya gora',
#  'gainesville',
#  'geraldton',
#  'bathsheba',
#  'baruun-urt',
#  'magistralnyy',
#  'barreirinhas',
#  'gorno-chuyskiy',
#  'dinsor',
#  'chokwe',
#  'kisoro',
#  'cumaribo',
#  'balkanabat',
#  'sungairaya',
#  'nara',
#  'tomatlan',
#  'chicama',
#  'mayo',
#  'tierranueva',
#  'kyra',
#  'viking',
#  'coos bay',
#  'songjianghe',
#  'kleck',
#  'verkhnetulomskiy',
#  'copiapo',
#  'tigil',
#  'zhob',
#  'aleksandrov gay',
#  'gold coast',
#  'omsukchan',
#  'ibra',
#  'tchollire',
#  'narsaq',
#  'santa quiteria',
#  'tshikapa',
#  'wahran',
#  'rungata',
#  'bolungarvik',
#  'kimbe',
#  'maralal',
#  'saint george',
#  'haines junction',
#  'kutum',
#  'surt',
#  'poltavka',
#  'sant julia de loria',
#  'aleksandrovskoye',
#  'sebeta',
#  'emmett',
#  'la palma',
#  'santa elena',
#  'los llanos de aridane',
#  'orlovskiy',
#  'vila franca do campo',
#  'hualmay',
#  'shingu',
#  'athens',
#  'hihifo',
#  'hwange',
#  'svetlaya',
#  'varberg',
#  'mollendo',
#  'valparaiso',
#  'manaus',
#  'novyy urgal',
#  'olafsvik',
#  'palestine',
#  'laguna de perlas',
#  'oranjestad',
#  'camacha',
#  'san felipe',
#  'tsabong',
#  'umm kaddadah',
#  'acajutla']

# %% [markdown]
# # API Calls

# %%
url = "https://api.openweathermap.org/data/2.5/weather?&units=Imperial"
# units = "Imperial"
city= "Carnarvon"
city_url = url+"&APPID="+weather_api_key+"&q="+city

 #create url for each city
# city_url = f"{url}&q={city}"

city_weather = requests.get(city_url).json()
# city_weather
        
#add a time delay to avoid oversing the API key
# time.sleep(2)

# max temp, humidity, and cloudiness 
city_lat = city_weather["coord"]["lat"]
city_long = city_weather["coord"]["lat"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_date = city_weather["dt"]
print(city.title(),city_lat, city_long, city_max_temp, city_humidity, city_clouds, city_wind, city_country, city_date)
# Out:
# Carnarvon -24.8667 -24.8667 62.67 100 100 18.41 AU 1659113901

# %%
url = "https://api.openweathermap.org/data/2.5/weather?&units=Imperial&APPID="+weather_api_key

# %%
#print to log
print("Data Retrieval")
print("---------------")

# url = "https://api.openweathermap.org/data/2.5/weather?&units=Imperial&APPID="+weather_api_key

# url = "https://api.openweathermap.org/data/2.5/weather?"
# units = "Imperial"

# query_url = f"{url}&APPID={weather_api_key}&units={units}&q="

#list of cities
city_data =[]

#create counters
record_count = 1
set_count = 1

#loop through all cities in our list
for i, city in enumerate(cities):
    if(i % 50 == 0 and i>= 50):
        set_count +=1
        record_count = 1
        time.sleep(2)
    #create url for each city
    city_url = url+"&q="+city
#     city_url = f"{url}&q={city}"
    
    #log the record and the set number
    print(f"Processing city #{record_count} in group #{set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()

        #add a time delay to avoid oversing the API key


        #max temp, humidity, and cloudiness 
        city_lat = city_weather["coord"]["lat"]
        city_long = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        #append the city info into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Long":city_long,
                         "Max Tem":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})
    except:
        #if errors occur, skip the city
        print(f"{city} has an error. Skipping...")
        pass
#indicate that data loading is complete
print("Data Retrieval Complete")
# Out:
# Data Retrieval
# ---------------
# Processing city #1 in group #1 | thompson
# Processing city #2 in group #1 | putina
# Processing city #3 in group #1 | sandanski
# Processing city #4 in group #1 | bredasdorp
# Processing city #5 in group #1 | illoqqortoormiut
# illoqqortoormiut has an error. Skipping...
# Processing city #6 in group #1 | neryungri
# Processing city #7 in group #1 | imbituba
# Processing city #8 in group #1 | grand river south east
# grand river south east has an error. Skipping...
# Processing city #9 in group #1 | upernavik
# Processing city #10 in group #1 | rikitea
# Processing city #11 in group #1 | hasaki
# Processing city #12 in group #1 | yellowknife
# Processing city #13 in group #1 | haibowan
# haibowan has an error. Skipping...
# Processing city #14 in group #1 | zhanatas
# zhanatas has an error. Skipping...
# Processing city #15 in group #1 | lebu
# Processing city #16 in group #1 | weymouth
# Processing city #17 in group #1 | arraial do cabo
# Processing city #18 in group #1 | jamestown
# Processing city #19 in group #1 | georgetown
# Processing city #20 in group #1 | ushuaia
# Processing city #21 in group #1 | hermanus
# Processing city #22 in group #1 | hobart
# Processing city #23 in group #1 | avarua
# Processing city #24 in group #1 | uruzgan
# Processing city #25 in group #1 | bubaque
# Processing city #26 in group #1 | barentsburg
# barentsburg has an error. Skipping...
# Processing city #27 in group #1 | nioro
# Processing city #28 in group #1 | tsihombe
# tsihombe has an error. Skipping...
# Processing city #29 in group #1 | butaritari
# Processing city #30 in group #1 | busselton
# Processing city #31 in group #1 | yar-sale
# Processing city #32 in group #1 | albany
# Processing city #33 in group #1 | novo aripuana
# Processing city #34 in group #1 | kapaa
# Processing city #35 in group #1 | shache
# Processing city #36 in group #1 | ponta do sol
# Processing city #37 in group #1 | saint andrews
# Processing city #38 in group #1 | uvalde
# Processing city #39 in group #1 | san patricio
# Processing city #40 in group #1 | kasongo
# Processing city #41 in group #1 | naryan-mar
# Processing city #42 in group #1 | vaitupu
# vaitupu has an error. Skipping...
# Processing city #43 in group #1 | talalayivka
# Processing city #44 in group #1 | saskylakh
# Processing city #45 in group #1 | pevek
# Processing city #46 in group #1 | hithadhoo
# Processing city #47 in group #1 | vaini
# Processing city #48 in group #1 | souillac
# Processing city #49 in group #1 | port-gentil
# Processing city #50 in group #1 | svetlyy
# Processing city #1 in group #2 | cape town
# Processing city #2 in group #2 | saint-philippe
# Processing city #3 in group #2 | amderma
# amderma has an error. Skipping...
# Processing city #4 in group #2 | vila
# Processing city #5 in group #2 | iqaluit
# Processing city #6 in group #2 | taolanaro
# taolanaro has an error. Skipping...
# Processing city #7 in group #2 | inongo
# Processing city #8 in group #2 | east london
# Processing city #9 in group #2 | chokurdakh
# Processing city #10 in group #2 | nanortalik
# Processing city #11 in group #2 | yuli
# Processing city #12 in group #2 | tashtyp
# Processing city #13 in group #2 | cabo san lucas
# Processing city #14 in group #2 | punta arenas
# Processing city #15 in group #2 | castro
# Processing city #16 in group #2 | bulnes
# Processing city #17 in group #2 | pilar
# Processing city #18 in group #2 | longyearbyen
# Processing city #19 in group #2 | dikson
# Processing city #20 in group #2 | khatanga
# Processing city #21 in group #2 | bethel
# Processing city #22 in group #2 | luganville
# Processing city #23 in group #2 | barrow
# Processing city #24 in group #2 | kaitangata
# Processing city #25 in group #2 | puerto ayora
# Processing city #26 in group #2 | quatre cocos
# Processing city #27 in group #2 | dwarka
# Processing city #28 in group #2 | mendahara
# mendahara has an error. Skipping...
# Processing city #29 in group #2 | tasiilaq
# Processing city #30 in group #2 | port alfred
# Processing city #31 in group #2 | jijiga
# Processing city #32 in group #2 | mataura
# Processing city #33 in group #2 | turukhansk
# Processing city #34 in group #2 | nizhneyansk
# nizhneyansk has an error. Skipping...
# Processing city #35 in group #2 | caraquet
# Processing city #36 in group #2 | gamba
# Processing city #37 in group #2 | bluff
# Processing city #38 in group #2 | mys shmidta
# mys shmidta has an error. Skipping...
# Processing city #39 in group #2 | porecatu
# Processing city #40 in group #2 | burgersdorp
# Processing city #41 in group #2 | mar del plata
# Processing city #42 in group #2 | luderitz
# Processing city #43 in group #2 | clyde river
# Processing city #44 in group #2 | saldanha
# Processing city #45 in group #2 | pemangkat
# Processing city #46 in group #2 | panguipulli
# Processing city #47 in group #2 | saint-paul
# Processing city #48 in group #2 | provideniya
# Processing city #49 in group #2 | veraval
# Processing city #50 in group #2 | meulaboh
# Processing city #1 in group #3 | ilulissat
# Processing city #2 in group #3 | geresk
# geresk has an error. Skipping...
# Processing city #3 in group #3 | moa
# Processing city #4 in group #3 | atuona
# Processing city #5 in group #3 | stornoway
# Processing city #6 in group #3 | kholbon
# Processing city #7 in group #3 | port blair
# Processing city #8 in group #3 | boende
# Processing city #9 in group #3 | nikolskoye
# Processing city #10 in group #3 | selma
# Processing city #11 in group #3 | kazachinskoye
# Processing city #12 in group #3 | norman wells
# Processing city #13 in group #3 | sawtell
# Processing city #14 in group #3 | andros town
# Processing city #15 in group #3 | carutapera
# Processing city #16 in group #3 | homer
# Processing city #17 in group #3 | sola
# Processing city #18 in group #3 | nahan
# Processing city #19 in group #3 | marang
# Processing city #20 in group #3 | galdar
# Processing city #21 in group #3 | talnakh
# Processing city #22 in group #3 | katsina
# Processing city #23 in group #3 | brae
# Processing city #24 in group #3 | san jeronimo
# Processing city #25 in group #3 | tuktoyaktuk
# Processing city #26 in group #3 | guerrero negro
# Processing city #27 in group #3 | pisco
# Processing city #28 in group #3 | nurota
# Processing city #29 in group #3 | faya
# Processing city #30 in group #3 | kawalu
# Processing city #31 in group #3 | saint-georges
# Processing city #32 in group #3 | walvis bay
# Processing city #33 in group #3 | halifax
# Processing city #34 in group #3 | kodiak
# Processing city #35 in group #3 | berlevag
# Processing city #36 in group #3 | hilo
# Processing city #37 in group #3 | seydi
# Processing city #38 in group #3 | cordele
# Processing city #39 in group #3 | rocha
# Processing city #40 in group #3 | hammerfest
# Processing city #41 in group #3 | lorengau
# Processing city #42 in group #3 | arman
# Processing city #43 in group #3 | kasempa
# Processing city #44 in group #3 | batamshinskiy
# Processing city #45 in group #3 | attawapiskat
# attawapiskat has an error. Skipping...
# Processing city #46 in group #3 | dongsheng
# Processing city #47 in group #3 | magugu
# Processing city #48 in group #3 | hun
# Processing city #49 in group #3 | chapleau
# Processing city #50 in group #3 | saint-joseph
# Processing city #1 in group #4 | te anau
# Processing city #2 in group #4 | comodoro rivadavia
# Processing city #3 in group #4 | mehamn
# Processing city #4 in group #4 | kailua
# Processing city #5 in group #4 | quelimane
# Processing city #6 in group #4 | manga
# Processing city #7 in group #4 | marawi
# Processing city #8 in group #4 | bolonchen
# bolonchen has an error. Skipping...
# Processing city #9 in group #4 | abu samrah
# Processing city #10 in group #4 | chuy
# Processing city #11 in group #4 | new norfolk
# Processing city #12 in group #4 | sentyabrskiy
# sentyabrskiy has an error. Skipping...
# Processing city #13 in group #4 | marcona
# marcona has an error. Skipping...
# Processing city #14 in group #4 | qaanaaq
# Processing city #15 in group #4 | sande
# Processing city #16 in group #4 | alofi
# Processing city #17 in group #4 | ngukurr
# ngukurr has an error. Skipping...
# Processing city #18 in group #4 | wanxian
# Processing city #19 in group #4 | umzimvubu
# umzimvubu has an error. Skipping...
# Processing city #20 in group #4 | cairns
# Processing city #21 in group #4 | buraydah
# Processing city #22 in group #4 | moose factory
# Processing city #23 in group #4 | rudsar
# Processing city #24 in group #4 | dmitriyevka
# Processing city #25 in group #4 | mount gambier
# Processing city #26 in group #4 | fortuna
# Processing city #27 in group #4 | lagoa
# Processing city #28 in group #4 | saint-augustin
# Processing city #29 in group #4 | camapua
# Processing city #30 in group #4 | sligo
# Processing city #31 in group #4 | constitucion
# Processing city #32 in group #4 | bambari
# Processing city #33 in group #4 | zachagansk
# zachagansk has an error. Skipping...
# Processing city #34 in group #4 | cidreira
# Processing city #35 in group #4 | tuatapere
# Processing city #36 in group #4 | jalu
# Processing city #37 in group #4 | omboue
# Processing city #38 in group #4 | klaksvik
# Processing city #39 in group #4 | port hardy
# Processing city #40 in group #4 | kushima
# Processing city #41 in group #4 | aviles
# Processing city #42 in group #4 | christchurch
# Processing city #43 in group #4 | flinders
# Processing city #44 in group #4 | honningsvag
# Processing city #45 in group #4 | torbay
# Processing city #46 in group #4 | wajid
# Processing city #47 in group #4 | saleilua
# saleilua has an error. Skipping...
# Processing city #48 in group #4 | bambous virieux
# Processing city #49 in group #4 | mahon
# Processing city #50 in group #4 | pangnirtung
# Processing city #1 in group #5 | dillon
# Processing city #2 in group #5 | peniche
# Processing city #3 in group #5 | morehead
# Processing city #4 in group #5 | avera
# Processing city #5 in group #5 | airai
# Processing city #6 in group #5 | samusu
# samusu has an error. Skipping...
# Processing city #7 in group #5 | port elizabeth
# Processing city #8 in group #5 | belcista
# Processing city #9 in group #5 | saint-francois
# Processing city #10 in group #5 | santa cruz de la palma
# Processing city #11 in group #5 | rawlins
# Processing city #12 in group #5 | caranavi
# Processing city #13 in group #5 | durant
# Processing city #14 in group #5 | moju
# Processing city #15 in group #5 | carnarvon
# Processing city #16 in group #5 | sungaipenuh
# Processing city #17 in group #5 | chapais
# Processing city #18 in group #5 | labuhan
# Processing city #19 in group #5 | vadso
# Processing city #20 in group #5 | eyl
# Processing city #21 in group #5 | tolu
# Processing city #22 in group #5 | edd
# Processing city #23 in group #5 | vao
# Processing city #24 in group #5 | ornes
# Processing city #25 in group #5 | havelock
# Processing city #26 in group #5 | sao filipe
# Processing city #27 in group #5 | palabuhanratu
# palabuhanratu has an error. Skipping...
# Processing city #28 in group #5 | svetlogorsk
# Processing city #29 in group #5 | komsomolskiy
# Processing city #30 in group #5 | erzin
# Processing city #31 in group #5 | kunyang
# Processing city #32 in group #5 | alugan
# Processing city #33 in group #5 | karratha
# Processing city #34 in group #5 | zolotkovo
# Processing city #35 in group #5 | kabwe
# Processing city #36 in group #5 | belushya guba
# belushya guba has an error. Skipping...
# Processing city #37 in group #5 | lagos
# Processing city #38 in group #5 | seoul
# Processing city #39 in group #5 | harper
# Processing city #40 in group #5 | general roca
# Processing city #41 in group #5 | kununurra
# Processing city #42 in group #5 | ye
# ye has an error. Skipping...
# Processing city #43 in group #5 | cangzhou
# Processing city #44 in group #5 | bengkulu
# Processing city #45 in group #5 | lompoc
# Processing city #46 in group #5 | aklavik
# Processing city #47 in group #5 | barawe
# barawe has an error. Skipping...
# Processing city #48 in group #5 | belfast
# Processing city #49 in group #5 | mikhaylovka
# Processing city #50 in group #5 | mayumba
# Processing city #1 in group #6 | victoria
# Processing city #2 in group #6 | valencia
# Processing city #3 in group #6 | alotau
# alotau has an error. Skipping...
# Processing city #4 in group #6 | issoire
# Processing city #5 in group #6 | salta
# Processing city #6 in group #6 | fort nelson
# Processing city #7 in group #6 | khani
# Processing city #8 in group #6 | beringovskiy
# Processing city #9 in group #6 | muroto
# Processing city #10 in group #6 | grand gaube
# Processing city #11 in group #6 | adrar
# Processing city #12 in group #6 | taltal
# Processing city #13 in group #6 | san jose
# Processing city #14 in group #6 | opobo
# opobo has an error. Skipping...
# Processing city #15 in group #6 | tiksi
# Processing city #16 in group #6 | talcahuano
# Processing city #17 in group #6 | krasnyy chikoy
# Processing city #18 in group #6 | mecca
# Processing city #19 in group #6 | mareeba
# Processing city #20 in group #6 | grindavik
# Processing city #21 in group #6 | kristiinankaupunki
# Processing city #22 in group #6 | cabedelo
# Processing city #23 in group #6 | zhaotong
# Processing city #24 in group #6 | gashua
# Processing city #25 in group #6 | pauini
# Processing city #26 in group #6 | rio gallegos
# Processing city #27 in group #6 | kruisfontein
# Processing city #28 in group #6 | cape coast
# Processing city #29 in group #6 | uribia
# Processing city #30 in group #6 | okhotsk
# Processing city #31 in group #6 | itarema
# Processing city #32 in group #6 | lavrentiya
# Processing city #33 in group #6 | faanui
# Processing city #34 in group #6 | norfolk
# Processing city #35 in group #6 | trairi
# Processing city #36 in group #6 | sakakah
# Processing city #37 in group #6 | ballina
# Processing city #38 in group #6 | plastun
# Processing city #39 in group #6 | aswan
# Processing city #40 in group #6 | young
# Processing city #41 in group #6 | north bend
# Processing city #42 in group #6 | gucheng
# Processing city #43 in group #6 | kahului
# Processing city #44 in group #6 | kapoeta
# Processing city #45 in group #6 | ponta delgada
# Processing city #46 in group #6 | dingle
# Processing city #47 in group #6 | ngunguru
# Processing city #48 in group #6 | laguna
# Processing city #49 in group #6 | osorno
# Processing city #50 in group #6 | sampit
# Processing city #1 in group #7 | makakilo city
# Processing city #2 in group #7 | point pleasant
# Processing city #3 in group #7 | salisbury
# Processing city #4 in group #7 | chulumani
# Processing city #5 in group #7 | carahue
# Processing city #6 in group #7 | yumen
# Processing city #7 in group #7 | gravelbourg
# Processing city #8 in group #7 | srednekolymsk
# Processing city #9 in group #7 | eureka
# Processing city #10 in group #7 | sitka
# Processing city #11 in group #7 | chara
# Processing city #12 in group #7 | abhar
# Processing city #13 in group #7 | nowa sol
# Processing city #14 in group #7 | warri
# Processing city #15 in group #7 | coahuayana
# Processing city #16 in group #7 | khartoum
# Processing city #17 in group #7 | kondinskoye
# Processing city #18 in group #7 | severo-kurilsk
# Processing city #19 in group #7 | ostrovnoy
# Processing city #20 in group #7 | taoudenni
# Processing city #21 in group #7 | san quintin
# Processing city #22 in group #7 | san cristobal
# Processing city #23 in group #7 | kholodnyy
# Processing city #24 in group #7 | juneau
# Processing city #25 in group #7 | petropavlovsk-kamchatskiy
# Processing city #26 in group #7 | mahebourg
# Processing city #27 in group #7 | broome
# Processing city #28 in group #7 | asau
# Processing city #29 in group #7 | arkhangelskoye
# Processing city #30 in group #7 | hornepayne
# Processing city #31 in group #7 | pokaran
# Processing city #32 in group #7 | anton lizardo
# Processing city #33 in group #7 | praia
# Processing city #34 in group #7 | pacific grove
# Processing city #35 in group #7 | abha
# Processing city #36 in group #7 | carballo
# Processing city #37 in group #7 | malwan
# malwan has an error. Skipping...
# Processing city #38 in group #7 | changji
# Processing city #39 in group #7 | muisne
# Processing city #40 in group #7 | gigmoto
# Processing city #41 in group #7 | san vicente
# Processing city #42 in group #7 | aksu
# Processing city #43 in group #7 | tuggurt
# tuggurt has an error. Skipping...
# Processing city #44 in group #7 | hambantota
# Processing city #45 in group #7 | egvekinot
# Processing city #46 in group #7 | birao
# Processing city #47 in group #7 | san juan
# Processing city #48 in group #7 | gatesville
# Processing city #49 in group #7 | sorland
# Processing city #50 in group #7 | ayni
# Processing city #1 in group #8 | muriti
# Processing city #2 in group #8 | leningradskiy
# Processing city #3 in group #8 | carora
# Processing city #4 in group #8 | andenes
# Processing city #5 in group #8 | puerto escondido
# Processing city #6 in group #8 | banda aceh
# Processing city #7 in group #8 | kamina
# Processing city #8 in group #8 | nuuk
# Processing city #9 in group #8 | nola
# Processing city #10 in group #8 | boguchany
# Processing city #11 in group #8 | hays
# Processing city #12 in group #8 | newton
# Processing city #13 in group #8 | xichang
# Processing city #14 in group #8 | hovd
# Processing city #15 in group #8 | qasigiannguit
# Processing city #16 in group #8 | husavik
# Processing city #17 in group #8 | ruwi
# Processing city #18 in group #8 | mount pleasant
# Processing city #19 in group #8 | hamilton
# Processing city #20 in group #8 | kavieng
# Processing city #21 in group #8 | rochester
# Processing city #22 in group #8 | vanavara
# Processing city #23 in group #8 | vidim
# Processing city #24 in group #8 | ribeira grande
# Processing city #25 in group #8 | maragogi
# Processing city #26 in group #8 | saleaula
# saleaula has an error. Skipping...
# Processing city #27 in group #8 | kerema
# Processing city #28 in group #8 | toliary
# toliary has an error. Skipping...
# Processing city #29 in group #8 | banjar
# Processing city #30 in group #8 | bose
# Processing city #31 in group #8 | jingdezhen
# Processing city #32 in group #8 | katyuzhanka
# Processing city #33 in group #8 | katsuura
# Processing city #34 in group #8 | bhuj
# Processing city #35 in group #8 | alta floresta
# Processing city #36 in group #8 | formosa do rio preto
# Processing city #37 in group #8 | salalah
# Processing city #38 in group #8 | belogradcik
# belogradcik has an error. Skipping...
# Processing city #39 in group #8 | tabou
# Processing city #40 in group #8 | namibe
# Processing city #41 in group #8 | pinhao
# Processing city #42 in group #8 | samalaeulu
# samalaeulu has an error. Skipping...
# Processing city #43 in group #8 | waipawa
# Processing city #44 in group #8 | leh
# Processing city #45 in group #8 | cherskiy
# Processing city #46 in group #8 | elva
# Processing city #47 in group #8 | krasnyy yar
# Processing city #48 in group #8 | cockburn town
# Processing city #49 in group #8 | chumikan
# Processing city #50 in group #8 | kiunga
# Processing city #1 in group #9 | northam
# Processing city #2 in group #9 | caramay
# Processing city #3 in group #9 | amposta
# Processing city #4 in group #9 | sarangani
# Processing city #5 in group #9 | vanimo
# Processing city #6 in group #9 | san andres
# Processing city #7 in group #9 | sumbawa
# sumbawa has an error. Skipping...
# Processing city #8 in group #9 | mafinga
# Processing city #9 in group #9 | perote
# Processing city #10 in group #9 | linfen
# Processing city #11 in group #9 | chipata
# Processing city #12 in group #9 | atar
# Processing city #13 in group #9 | half moon bay
# Processing city #14 in group #9 | montes claros
# Processing city #15 in group #9 | epe
# Processing city #16 in group #9 | lephepe
# lephepe has an error. Skipping...
# Processing city #17 in group #9 | ciudad bolivar
# Processing city #18 in group #9 | codrington
# Processing city #19 in group #9 | ketchikan
# Processing city #20 in group #9 | shenjiamen
# Processing city #21 in group #9 | posse
# Processing city #22 in group #9 | chaa-khol
# chaa-khol has an error. Skipping...
# Processing city #23 in group #9 | kolondieba
# Processing city #24 in group #9 | opuwo
# Processing city #25 in group #9 | ixtapa
# Processing city #26 in group #9 | stade
# Processing city #27 in group #9 | nemuro
# Processing city #28 in group #9 | pontes e lacerda
# Processing city #29 in group #9 | ambilobe
# Processing city #30 in group #9 | cayenne
# Processing city #31 in group #9 | antofagasta
# Processing city #32 in group #9 | dingtao
# Processing city #33 in group #9 | bow island
# Processing city #34 in group #9 | mpanda
# Processing city #35 in group #9 | saint anthony
# Processing city #36 in group #9 | nalut
# Processing city #37 in group #9 | agua prieta
# Processing city #38 in group #9 | yemanzhelinsk
# Processing city #39 in group #9 | ahipara
# Processing city #40 in group #9 | mizan teferi
# Processing city #41 in group #9 | hervey bay
# Processing city #42 in group #9 | port pirie
# Processing city #43 in group #9 | yaan
# Processing city #44 in group #9 | doha
# Processing city #45 in group #9 | nakhon thai
# Processing city #46 in group #9 | calama
# Processing city #47 in group #9 | chicaman
# Processing city #48 in group #9 | la ronge
# Processing city #49 in group #9 | acari
# Processing city #50 in group #9 | katangli
# Processing city #1 in group #10 | sechura
# Processing city #2 in group #10 | bachi-yurt
# Processing city #3 in group #10 | mbini
# Processing city #4 in group #10 | ust-tsilma
# Processing city #5 in group #10 | camana
# Processing city #6 in group #10 | dunedin
# Processing city #7 in group #10 | saryshagan
# saryshagan has an error. Skipping...
# Processing city #8 in group #10 | zyryanka
# Processing city #9 in group #10 | nanakuli
# Processing city #10 in group #10 | nyurba
# Processing city #11 in group #10 | praia da vitoria
# Processing city #12 in group #10 | meyungs
# meyungs has an error. Skipping...
# Processing city #13 in group #10 | aleksandrovka
# Processing city #14 in group #10 | knysna
# Processing city #15 in group #10 | moindou
# Processing city #16 in group #10 | goma
# Processing city #17 in group #10 | margate
# Processing city #18 in group #10 | ondorhaan
# ondorhaan has an error. Skipping...
# Processing city #19 in group #10 | jiquipilas
# Processing city #20 in group #10 | vrangel
# Processing city #21 in group #10 | katsiveli
# katsiveli has an error. Skipping...
# Processing city #22 in group #10 | pimentel
# Processing city #23 in group #10 | nepalganj
# nepalganj has an error. Skipping...
# Processing city #24 in group #10 | glenwood springs
# Processing city #25 in group #10 | fairbanks
# Processing city #26 in group #10 | rio cuarto
# Processing city #27 in group #10 | zalesovo
# Processing city #28 in group #10 | pangai
# Processing city #29 in group #10 | hay river
# Processing city #30 in group #10 | sorvag
# sorvag has an error. Skipping...
# Processing city #31 in group #10 | harboore
# Processing city #32 in group #10 | mayya
# Processing city #33 in group #10 | bur gabo
# bur gabo has an error. Skipping...
# Processing city #34 in group #10 | nisia floresta
# Processing city #35 in group #10 | novopokrovka
# Processing city #36 in group #10 | sibu
# Processing city #37 in group #10 | jacareacanga
# Processing city #38 in group #10 | naze
# Processing city #39 in group #10 | ajdabiya
# Processing city #40 in group #10 | kudahuvadhoo
# Processing city #41 in group #10 | saiha
# Processing city #42 in group #10 | nouadhibou
# Processing city #43 in group #10 | petropavlovka
# Processing city #44 in group #10 | leua
# Processing city #45 in group #10 | esperance
# Processing city #46 in group #10 | coihaique
# Processing city #47 in group #10 | yershichi
# Processing city #48 in group #10 | kamenka
# Processing city #49 in group #10 | hami
# Processing city #50 in group #10 | goderich
# Processing city #1 in group #11 | kiknur
# Processing city #2 in group #11 | amahai
# Processing city #3 in group #11 | port hedland
# Processing city #4 in group #11 | mangrol
# Processing city #5 in group #11 | hof
# Processing city #6 in group #11 | xining
# Processing city #7 in group #11 | sines
# Processing city #8 in group #11 | broken hill
# Processing city #9 in group #11 | buchanan
# Processing city #10 in group #11 | mocajuba
# Processing city #11 in group #11 | viedma
# Processing city #12 in group #11 | dossor
# Processing city #13 in group #11 | ginir
# Processing city #14 in group #11 | kholm-zhirkovskiy
# Processing city #15 in group #11 | porto novo
# Processing city #16 in group #11 | tunduru
# tunduru has an error. Skipping...
# Processing city #17 in group #11 | kloulklubed
# Processing city #18 in group #11 | ugoofaaru
# Processing city #19 in group #11 | kupang
# Processing city #20 in group #11 | almansa
# Processing city #21 in group #11 | novoanninskiy
# Processing city #22 in group #11 | thinadhoo
# Processing city #23 in group #11 | krasnoselkup
# Processing city #24 in group #11 | songea
# Processing city #25 in group #11 | bahir dar
# Processing city #26 in group #11 | shelburne
# Processing city #27 in group #11 | puerto baquerizo moreno
# Processing city #28 in group #11 | diffa
# Processing city #29 in group #11 | belaya gora
# Processing city #30 in group #11 | gainesville
# Processing city #31 in group #11 | geraldton
# Processing city #32 in group #11 | bathsheba
# Processing city #33 in group #11 | baruun-urt
# Processing city #34 in group #11 | magistralnyy
# Processing city #35 in group #11 | barreirinhas
# Processing city #36 in group #11 | gorno-chuyskiy
# gorno-chuyskiy has an error. Skipping...
# Processing city #37 in group #11 | dinsor
# dinsor has an error. Skipping...
# Processing city #38 in group #11 | chokwe
# Processing city #39 in group #11 | kisoro
# Processing city #40 in group #11 | cumaribo
# cumaribo has an error. Skipping...
# Processing city #41 in group #11 | balkanabat
# Processing city #42 in group #11 | sungairaya
# Processing city #43 in group #11 | nara
# Processing city #44 in group #11 | tomatlan
# Processing city #45 in group #11 | chicama
# Processing city #46 in group #11 | mayo
# Processing city #47 in group #11 | tierranueva
# Processing city #48 in group #11 | kyra
# Processing city #49 in group #11 | viking
# Processing city #50 in group #11 | coos bay
# Processing city #1 in group #12 | songjianghe
# Processing city #2 in group #12 | kleck
# kleck has an error. Skipping...
# Processing city #3 in group #12 | verkhnetulomskiy
# Processing city #4 in group #12 | copiapo
# Processing city #5 in group #12 | tigil
# Processing city #6 in group #12 | zhob
# Processing city #7 in group #12 | aleksandrov gay
# Processing city #8 in group #12 | gold coast
# Processing city #9 in group #12 | omsukchan
# Processing city #10 in group #12 | ibra
# Processing city #11 in group #12 | tchollire
# Processing city #12 in group #12 | narsaq
# Processing city #13 in group #12 | santa quiteria
# Processing city #14 in group #12 | tshikapa
# Processing city #15 in group #12 | wahran
# wahran has an error. Skipping...
# Processing city #16 in group #12 | rungata
# rungata has an error. Skipping...
# Processing city #17 in group #12 | bolungarvik
# bolungarvik has an error. Skipping...
# Processing city #18 in group #12 | kimbe
# Processing city #19 in group #12 | maralal
# Processing city #20 in group #12 | saint george
# Processing city #21 in group #12 | haines junction
# Processing city #22 in group #12 | kutum
# Processing city #23 in group #12 | surt
# Processing city #24 in group #12 | poltavka
# Processing city #25 in group #12 | sant julia de loria
# Processing city #26 in group #12 | aleksandrovskoye
# Processing city #27 in group #12 | sebeta
# Processing city #28 in group #12 | emmett
# Processing city #29 in group #12 | la palma
# Processing city #30 in group #12 | santa elena
# Processing city #31 in group #12 | los llanos de aridane
# Processing city #32 in group #12 | orlovskiy
# Processing city #33 in group #12 | vila franca do campo
# Processing city #34 in group #12 | hualmay
# Processing city #35 in group #12 | shingu
# Processing city #36 in group #12 | athens
# Processing city #37 in group #12 | hihifo
# hihifo has an error. Skipping...
# Processing city #38 in group #12 | hwange
# Processing city #39 in group #12 | svetlaya
# Processing city #40 in group #12 | varberg
# Processing city #41 in group #12 | mollendo
# Processing city #42 in group #12 | valparaiso
# Processing city #43 in group #12 | manaus
# Processing city #44 in group #12 | novyy urgal
# Processing city #45 in group #12 | olafsvik
# Processing city #46 in group #12 | palestine
# Processing city #47 in group #12 | laguna de perlas
# Processing city #48 in group #12 | oranjestad
# Processing city #49 in group #12 | camacha
# Processing city #50 in group #12 | san felipe
# Processing city #1 in group #13 | tsabong
# Processing city #2 in group #13 | umm kaddadah
# Processing city #3 in group #13 | acajutla
# Data Retrieval Complete

# %% [markdown]
# # Convert Raw Data to DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#          City      Lat     Long  Max Tem  Humidity  Cloudiness  Wind Speed  \
# 0    Thompson  55.7435  55.7435    65.53        74         100        9.24
# 1      Putina -15.4667 -15.4667    50.09        35           6        5.19
# 2   Sandanski  41.5667  41.5667    83.26        48          68        3.74
# 3  Bredasdorp -34.5322 -34.5322    50.85        72         100       11.27
# 4   Neryungri  56.6709  56.6709    54.46        88           0        5.97
#
#   Country        Date
# 0      CA  1659114078
# 1      PE  1659114134
# 2      BG  1659114135
# 3      ZA  1659114135
# 4      RU  1659114136

# %%
city_data_pd.to_csv("city_weather_data.csv")

# %%
city_data_pd=pd.read_csv("city_weather_data.csv")
city_data_pd.head()
# Out:
#    Unnamed: 0        City      Lat     Long  Max Tem  Humidity  Cloudiness  \
# 0           0    Thompson  55.7435  55.7435    65.53        74         100
# 1           1      Putina -15.4667 -15.4667    50.09        35           6
# 2           2   Sandanski  41.5667  41.5667    83.26        48          68
# 3           3  Bredasdorp -34.5322 -34.5322    50.85        72         100
# 4           4   Neryungri  56.6709  56.6709    54.46        88           0
#
#    Wind Speed Country        Date
# 0        9.24      CA  1659114078
# 1        5.19      PE  1659114134
# 2        3.74      BG  1659114135
# 3       11.27      ZA  1659114135
# 4        5.97      RU  1659114136

# %%
city_data_pd.describe()
# Out:
#        Unnamed: 0         Lat        Long     Max Tem    Humidity  Cloudiness  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean   274.500000   19.943439   19.943439   70.856382   67.301818   56.045455
# std    158.915596   32.953157   32.953157   14.597113   21.114136   37.215805
# min      0.000000  -54.800000  -54.800000   32.560000    7.000000    0.000000
# 25%    137.250000   -6.114200   -6.114200   60.657500   55.000000   20.000000
# 50%    274.500000   23.078800   23.078800   72.515000   72.000000   63.500000
# 75%    411.750000   46.863125   46.863125   81.330000   83.000000   95.000000
# max    549.000000   78.218600   78.218600  113.760000  100.000000  100.000000
#
#        Wind Speed          Date
# count  550.000000  5.500000e+02
# mean     8.131800  1.659114e+09
# std      5.299127  1.382503e+02
# min      0.000000  1.659114e+09
# 25%      4.000000  1.659114e+09
# 50%      7.020000  1.659114e+09
# 75%     10.715000  1.659114e+09
# max     29.930000  1.659114e+09

# %% [markdown]
# # Inspect the data and remove the cities with >100% humidity

# %%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"]>100)].index

print(dirty_city_data)
# Out:
# Int64Index([], dtype='int64')

# %%
#clean data set by removing cities 
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#    Unnamed: 0        City      Lat     Long  Max Tem  Humidity  Cloudiness  \
# 0           0    Thompson  55.7435  55.7435    65.53        74         100
# 1           1      Putina -15.4667 -15.4667    50.09        35           6
# 2           2   Sandanski  41.5667  41.5667    83.26        48          68
# 3           3  Bredasdorp -34.5322 -34.5322    50.85        72         100
# 4           4   Neryungri  56.6709  56.6709    54.46        88           0
#
#    Wind Speed Country        Date
# 0        9.24      CA  1659114078
# 1        5.19      PE  1659114134
# 2        3.74      BG  1659114135
# 3       11.27      ZA  1659114135
# 4        5.97      RU  1659114136

# %%
#extract required info
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Tem"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

#export city data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# # Plotting the Data

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor = "black", linewidths=1, marker="o", alpha=0.8, label="Cities")
#add graph properties
plt.title("City Latitude vs Max Temps")
plt.ylabel("Max temps in F")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor = "black", linewidths=1, marker="o", alpha=0.8, label="Cities")
#add graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity in %")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Latitude vs Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor = "black", linewidths=1, marker="o", alpha=0.8, label="Cities")
#add graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness in %")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor = "black", linewidths=1, marker="o", alpha=0.8, label="Cities")
#add graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed mph")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
#create a function to create linear regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
   #run a regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y - "+ str(round(slope,2))+ "x +"+ str(round(intercept,2))
    
    #plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is:{rvalue**2}")
    plt.show()

# %%
#create northern and southern hemisphere df
north_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >=0)]
south_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] <0)]

# %% [markdown]
# # Northern Hemisphere - Max temps vs Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Max Tem"]
plot_linear_regression(x_values, y_values, 'Max Temp',(34,70))
# Out:
# The r-value is:0.4206069826507413

# %% [markdown]
# # Southern Hemisphere - Max temps vs Latitude Linear Regression

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Max Tem"]
plot_linear_regression(x_values, y_values, 'Max Temp',(-34,60))
# Out:
# The r-value is:0.6082845888990928

# %% [markdown]
# # Northern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(16,73))
# Out:
# The r-value is:0.008050847916419246

# %% [markdown]
# # Southern Hemisphere - Humidity vs Latitude Linear Regression

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(-6,30))
# Out:
# The r-value is:0.0035826906168340794

# %% [markdown]
# # Northern Hemisphere - Cloudiness vs Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(8,40))
# Out:
# The r-value is:0.007982459357130493

# %% [markdown]
# # Southern Hemisphere - Cloudiness vs Latitude Linear Regression

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(-8,40))
# Out:
# The r-value is:0.0581453558639422

# %% [markdown]
# # Northern Hemisphere - Wind Speed vs Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(18,40))
# Out:
# The r-value is:0.010145931808027593

# %% [markdown]
# # Southern Hemisphere - Wind Speed vs Latitude Linear Regression

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(-18,40))
# Out:
# The r-value is:0.060369826769313704
